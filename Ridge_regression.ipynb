# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('boston.csv')
df.shape
# Out:
# (506, 14)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# !pip3 install mlxtend
# Out:
# ...
#   Obtaining dependency information for mlxtend from https://files.pythonhosted.org/packages/73/da/d5d77a9a7a135c948dbf8d3b873655b105a152d69e590150c83d23c3d070/mlxtend-0.23.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.2 MB/s eta 0:00:0000:0100:010m
# ...

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
cols = ["LSTAT","B","TAX","MEDV"]
scatterplotmatrix(df[cols].values,figsize=(10,8),names = cols,alpha = 0.5)
plt.tight_layout()
plt.show()

# %%
# here we don't have a good correlation
#so we add a column to the cols

# %%
cols = ["LSTAT","B","TAX","RM","MEDV"]
scatterplotmatrix(df[cols].values,figsize=(10,8),names = cols,alpha = 0.5)
plt.tight_layout()
plt.show()

# %%
# here we can see that there is perfect correlation between RM and Medv
# So RM is the most important feature in the data

# %%
from mlxtend.plotting import heatmap
cm = np.corrcoef(df[cols].values.T)
hm = heatmap(cm,row_names=cols,column_names=cols)
plt.show()

# %%
plt.hist(df['MEDV'])
plt.title("Histogram")
plt.show()

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state=10)

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)

# %%
ridge = ridge.fit(x_train,y_train)

# %%
y_pred = ridge.predict(x_test)

# %%
print("Slope : %.2f"%ridge.coef_[0])
# Out:
# Slope : -0.12

# %%
print("Intercept : %.2f"% ridge.intercept_)
# Out:
# Intercept : 28.58

# %%
from sklearn.metrics import mean_squared_error,r2_score
mean_squared_error(y_pred,y_test)
# Out:
# 33.06633326875668

# %%
np.sqrt(mean_squared_error(y_pred,y_test))
# Out:
# 5.750333318057022

# %%
print("R-Squared value is : %.2f" % ridge.score(x_test,y_test))
# Out:
# R-Squared value is : 0.67

# %%
# we can change the value by changing the value of alpha
